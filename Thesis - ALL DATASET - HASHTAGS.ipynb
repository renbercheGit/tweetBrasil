# %% [markdown]
# # Data Analysis - All dataset

# %% [markdown]
# Libraries

# %%
import pandas as pd
import nltk
import re
import string

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter,OrderedDict
from nltk.tokenize import RegexpTokenizer

nltk.download('stopwords')
stop = stopwords.words('portuguese')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anape\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anape\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\anape\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anape\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Dataframe

# %%
df =  pd.read_csv('tweet_all.csv',  sep=';', on_bad_lines='skip',lineterminator='\r',low_memory=False)
print(len(df))
text = df['text']
# Out:
# 858832

# %% [markdown]
# Cleaning 1 - Removing rows with specific words (the whole row, because is related to a subject that won't be useful)

# %%
# Specify the list of specific words you want to filter out
specific_words = ['trânsito', 'rodovia', 'tráfego', 'ecovias','TIM', 'tim']

# Fill NaN values in the 'text' column with an empty string
df['text'].fillna('', inplace=True)

# Create a boolean mask for rows containing specific words in the 'text' column
mask = df['text'].str.contains('|'.join(specific_words), case=False)

# Apply the mask to filter out rows with specific words
df_filtered = df[~mask]

print("Filtered DataFrame length:", len(df_filtered))
# Out:
# Filtered DataFrame length: 794807

# %%
#print(df_filtered.head(50))

# %% [markdown]
# Cleaning 2 - removing URLs

# %%
# Define a regular expression pattern to match URLs
url_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'

# Remove URLs from the 'text' column using regular expressions
df_filtered.loc[:, 'text'] = df_filtered['text'].str.replace(url_pattern, '', regex=True)

print(df_filtered.head(10))
# Out:
#                    id                                               text  \
# 0  561675512373067776  RT @cartacapital: A União Europeia tem virado ...
# 1  561676165795287040  RT @cartacapital: A União Europeia tem virado ...
# 2  561677292938592256                         Va estar refugiado seguro.
# 3  561677511655190528  RT @cartacapital: A União Europeia tem virado ...
# 4  561678375488872448                                          Refugiado
# 5  561678577985654784  RT @cartacapital: A União Europeia tem virado ...
# 6  561679087073107968    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# 7  561679088255901696    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# 8  561680173494706177  RT @JornalOGlobo: 'A escalada do sofrimento do...
# 9  561682696871882752                  E EU FUI PEGA NA IMIGRAÇÃO!!!!!!!
#
#             created_at   author_id lang in_reply_to_user_id
# 0  2015-02-01 00:00:52    45630114   pt                None
# ...

# %% [markdown]
# Cleaning 3 - removing specific words from the column 'text'

# %%
# Define a list of specific words you want to remove
specific_words_to_remove = ['RT']

# Create a regular expression pattern to match the specific words
pattern = r'\b(?:' + '|'.join(specific_words_to_remove) + r')\b'

# Remove the specific words from the 'text' column using regular expressions
df_filtered.loc[:, 'text'] = df_filtered['text'].str.replace(pattern, '', regex=True)

print(df_filtered.head(50))
# Out:
#                     id                                               text  \
# 0   561675512373067776   @cartacapital: A União Europeia tem virado as...
# 1   561676165795287040   @cartacapital: A União Europeia tem virado as...
# 2   561677292938592256                         Va estar refugiado seguro.
# 3   561677511655190528   @cartacapital: A União Europeia tem virado as...
# 4   561678375488872448                                          Refugiado
# 5   561678577985654784   @cartacapital: A União Europeia tem virado as...
# 6   561679087073107968    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# 7   561679088255901696    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# 8   561680173494706177   @JornalOGlobo: 'A escalada do sofrimento dos ...
# 9   561682696871882752                  E EU FUI PEGA NA IMIGRAÇÃO!!!!!!!
# 10  561682887834370048  África Central: fotos retratam dramas médicos ...
# 11  561683636249190400   @cartacapital: A União Europeia tem virado as...
# ...

# %% [markdown]
# Cleaning 4 - removing usernames and mentions

# %%
# Define a regular expression pattern to match mentions (usernames)
mention_pattern = r'@\w+'

# Remove mentions from the 'text' column using regular expressions
df_filtered.loc[:, 'text'] = df_filtered['text'].str.replace(mention_pattern, '', regex=True)

print(df_filtered.head(50))
# Out:
#                     id                                               text  \
# 0   561675512373067776   : A União Europeia tem virado as costas aos r...
# 1   561676165795287040   : A União Europeia tem virado as costas aos r...
# 2   561677292938592256                         Va estar refugiado seguro.
# 3   561677511655190528   : A União Europeia tem virado as costas aos r...
# 4   561678375488872448                                          Refugiado
# 5   561678577985654784   : A União Europeia tem virado as costas aos r...
# 6   561679087073107968    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# 7   561679088255901696    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# 8   561680173494706177   : 'A escalada do sofrimento dos refugiados', ...
# 9   561682696871882752                  E EU FUI PEGA NA IMIGRAÇÃO!!!!!!!
# 10  561682887834370048  África Central: fotos retratam dramas médicos ...
# 11  561683636249190400   : A União Europeia tem virado as costas aos r...
# ...

# %% [markdown]
# TOKENIZATION

# %%
# Tokenize the text in the 'text' column using NLTK
df_filtered['tokens'] = df_filtered['text'].apply(word_tokenize)

# Display the first 10 rows with tokenized text
print(df_filtered[['text', 'tokens']].head(10))
# Out:
# C:\Users\anape\AppData\Local\Temp\ipykernel_18960\3747244384.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['tokens'] = df_filtered['text'].apply(word_tokenize)
#                                                 text  \
# 0   : A União Europeia tem virado as costas aos r...
# 1   : A União Europeia tem virado as costas aos r...
# 2                         Va estar refugiado seguro.
# 3   : A União Europeia tem virado as costas aos r...
# 4                                          Refugiado
# 5   : A União Europeia tem virado as costas aos r...
# 6    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# 7    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# 8   : 'A escalada do sofrimento dos refugiados', ...
# ...

# %% [markdown]
# Cleaning - Remove stopwords

# %%
df_filtered['filtered_tokens'] = df_filtered['tokens'].apply(lambda tokens: [word for word in tokens if word.lower() not in stop])

# Display the first 10 rows with tokenized and filtered text
print(df_filtered[['text', 'filtered_tokens']].head(10))
# Out:
# C:\Users\anape\AppData\Local\Temp\ipykernel_18960\1914856274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['filtered_tokens'] = df_filtered['tokens'].apply(lambda tokens: [word for word in tokens if word.lower() not in stop])
#                                                 text  \
# 0   : A União Europeia tem virado as costas aos r...
# 1   : A União Europeia tem virado as costas aos r...
# 2                         Va estar refugiado seguro.
# 3   : A União Europeia tem virado as costas aos r...
# 4                                          Refugiado
# 5   : A União Europeia tem virado as costas aos r...
# 6    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# 7    [Vídeo] IMIGRAÇÃO - Canal - Porta dos Fundos -
# ...

# %% [markdown]
# IDENTIFYING HASHTAGS

# %%
# Define a regular expression pattern to match hashtags
hashtag_pattern = r'#\w+'

# Extract hashtags from the 'text' column using regular expressions
hashtags_list = df['text'].str.findall(hashtag_pattern, flags=re.IGNORECASE)

# Flatten the list of lists
all_hashtags = [tag.lower() for sublist in hashtags_list for tag in sublist]

# Count the occurrences of each hashtag
hashtag_counts = {}
for hashtag in all_hashtags:
    hashtag_counts[hashtag] = hashtag_counts.get(hashtag, 0) + 1

# Organize the hashtag counts in descending order
sorted_hashtag_counts = dict(sorted(hashtag_counts.items(), key=lambda item: item[1], reverse=True))

# in descending order
for hashtag, count in sorted_hashtag_counts.items():
    print(f"{hashtag}: {count}")
# Out:
# #refugiados: 7521
# #g1: 6819
# #operacaobetalab: 4020
# #timbeta: 3102
# #imigrantes: 2796
# #venezuela: 2319
# #rt: 2247
# #brasil: 2149
# #sdv: 1941
# #eua: 1886
# #alemanha: 1808
# #imigração: 1643
# #tvonline: 1545
# #comosrefugiados: 1439
# #itália: 1314
# #notícias: 1264
# #betacaralhudosan: 1227
# #transitosp: 1087
# #mundo: 1081
# #hungria: 1051
# #acnur: 1033
# #bbb18: 1030
# #frança: 1028
# #sp: 991
# #noticias: 929
# #rio2016: 912
# #vetatemer: 872
# #news: 863
# #betalab: 820
# #seumelhorcaminho: 819
# #síria: 713
# #anchieta: 652
# #migrantes: 622
# #suécia: 618
# #grecia: 604
# #onu: 602
# #vídeo: 597
# #internacional: 580
# #órfãosdaterra: 557
# #msf: 556
# #operaçãoacolhida: 536
# #roraima: 532
# #uol: 510
# #paris: 507
# #canada: 486
# #cuba: 463
# #líbia: 454
# #europa: 439
# #refugees: 433
# #rt1: 428
# #semanarenova: 422
# #imigracao: 406
# #nordestecombolsonaro: 405
# #grécia: 402
# #méxico: 391
# #refugiado: 389
# #canadá: 389
# #japão: 385
# #portugal: 385
# ...

# %%
# Flatten the list of lists and convert to a set to get unique hashtags
unique_hashtags = set([tag.lower() for sublist in hashtags_list for tag in sublist])

# Count the number of different hashtags
num_unique_hashtags = len(unique_hashtags)

print("Number of different hashtags:", num_unique_hashtags)
# Out:
# Number of different hashtags: 24227

# %%
# List of unwanted hashtags
unwanted_hashtags = ['#operacaobetalab', '#timbeta' , '#sdv' , '#betacaralhudosan' , '#transitosp' , '#bbb18' , '#rio2016' , '#betalab' , '#seumelhorcaminho' , '#anchieta' , '#órfãosdaterra' , '#rt1' , '#semanarenova' , '#transito' , '#sigodevolta' , '#orfaosdaterra' , '#s' , '#betac' , '#mundoaominuto' , '#bbb' , '#pré_hospitalar' , '#angelinajolie' , '#sanvalentin' , '#umrei' , '#coelhão' , '#grammys' , '#retrospectivarenova' , '#zs' , '#feedly' , '#ebc' , '#plantãocorinthians' , '#teamfollowback' , '#spfotos' , '#rgp' , '#garraseguros' , '#bandeirantes' , '#beta' , '#masterchefbr' , '#poenaradiosulamericatransito' , '#rohingya' , '#dayumbetauhu' , '#edgar' , '#arturo' , '#operecaobetalab' , '#estradas' , '#seguesigodevolta' , '#moments' , '#acamposxp' , '#guabiruba' , '#oscars' , '#婚活' , '#deai' , '#セフレ' , '#メル友' , '#cpbr8' , '#mpn' , '#teamkaysar' , '#timbetalab' , '#profissãorepórter' , '#easycanada' , '#bbb16' , '#mali' , '#timbo' , '#kaysar' , '#museumweek' , '#sp1' , '#muitoalémdofutebol' , '#criciuma' , '#redebbb' , '#calais' , '#turismo' , '#afp' , '#geledes' , '#12hnerds' , '#palmeiras105anos' , '#2' , '#idomeni' , '#aparcomomundo' , '#aprendinoenem' , '#botize' , '#trânsito' , '#acidente_de_trânsito' , '#rodovia' , '#cm' , '#ocarroqueéasuacara' , '#reinounido' , '#bdsp' , '#enem2019' , '#dicas' , '#rodoanel' , '#bundesliga' , '#tbt' , '#cerimoniadeabertura' , '#1' , '#ocupasenado' , '#sxsw' , '#bbb15' , '#emprego' , '#timb' , '#3' , '#televansbh' , '#bhvans' , '#rohingyas' , '#missãobeta' , '#pais' , '#podcast' , '#cinema' , '#equador' , '#skoob' , '#vejafato2015' , '#programadoporchat' , '#sextadetremurasdv' , '#galo' , '#retrospectiva2015' , '#agrandejogada' , '#photo' , '#crianças' , '#capricho' , '#paisaominuto' , '#paixãodopovo' , '#jubileu' , '#e' , '#futebol' , '#manaus' , '#timão' , '#oitnb' , '#acidente' , '#globeleza' , '#timedospovos' , '#ses' , '#uclfinal' , '#redeaprizion' , '#cop25' , '#l2' , '#encontro' , '#operaçãoretweet' , '#volemacollir' , '#filme' , '#fb' , '#tribunadonorte' , '#rbsrio16' , '#rodovias' , '#frasesdomeutumulo' , '#personalizada1' , '#ikea' , '#sanderlei' , '#acel' , '#i5gornascimento' , '#rot' , '#intercambio' , '#g' , '#ebcradio' , '#kaysardadour' , '#closeerradoéquando' , '#expresso' , '#atendimento_pré_hospitalar' , '#193r' , '#masterchef100' , '#sui' , '#bomdia' , '#férias' , '#forafamilialima' , '#sqn' , '#cumbrepanama' , '#globoesporte' , '#retrô' , '#globodeouro' , '#p76' , '#incêndio' , '#midiario' , '#rodaviva' , '#joaomundi' , '#gauchahoje' , '#tánoleiajá' , '#dançadosfamosos' , '#ecovias' , '#blumenau' , '#avenidadosbandeirantes' , '#proenemaovivo' , '#kandel' , '#orfãosdaterra' , '#alagamento' , '#travel' , '#nippon' , '#diadonordestino' , '#estudar' , '#minhafuga' , '#freeopenarms' , '#orfaosdaterrra' , '#multintercambio' , '#ariquemesonline' , '#timlabs' , '#p73' , '#bgs2016' , '#tecerfuturos' , '#vice' , '#édecasa' , '#noarnacbn' , '#teenwolf' , '#texas' , '#intercâmbio' , '#googlealerts' , '#aquarius' , '#botafogo' , '#enem' , '#grandeabc' , '#folheando' , '#beer' , '#4' , '#movie' , '#foralucas' , '#viagens' , '#exposição' , '#variedades' , '#rafaelsouzagame' , '#circulonamega' , '#forbesunder30' , '#love' , '#grupoaquecendo' , '#uk' , '#teatro' , '#cruzeirotimedopovo' , '#com' , '#ceuta' , '#podeconfiar' , '#delegacia' , '#agenda' , '#entérate' , '#73' , '#jogos2016' , '#odaat' , '#tecnologia' , '#soundcloud' , '#esporte' , '#saúde' , '#comemoração' , '#tim' , '#literatura' , '#periscope' , '#r' , '#lovetwitter' , '#nósnamega' , '#mãoamiga' , '#debateaparecida' , '#v' , '#imagensdodia' , '#copaacerjitaipava2016' , '#alagoasalerta' , '#ango' , '#judo' , '#ibelong' , '#soteu' , '#saude' , '#dgabc' , '#marginalpinheiros' , '#podcastfriday' , '#enem2016' , '#wea' , '#yazidigenocide' , '#superlidas' , '#globolixo' , '#15anos' , '#atençãonasestradas' , '#football' , '#p72' , '#mariafumaça' , '#one4' , '#egaylity' , '#gdragon' , '#opcoiote' , '#maiscruz' , '#lgbt' , '#instagram' , '#etl' , '#falabrasil' , '#empreendedorismo' , '#poenaradiosulamericasegurostransito' , '#rbr' , '#unga' , '#olimpíadas' , '#luansantana' , '#bbb19' , '#secretsmw' , '#feriado' , '#esquenta' , '#stigmabase' , '#p' , '#democraciajá' , '#spotted' , '#yazidiplight' , '#estadao' , '#fernandogabeira' , '#betaquerlab' , '#camil' , '#valoremjogo' , '#rdc' , '#tvonlline' , '#tecmundo' , '#expressentry' , '#cerveja' , '#exclusivo' , '#5' , '#mis' , '#pfemação' , '#trip' , '#estágio' , '#verguenza' , '#yazidis' , '#tweetcampeão' , '#viena' , '#lucas' , '#democraciasim' , '#espalhandoamorls' , '#p75' , '#empleo' , '#megaartesanal' , '#papodesegundanognt' , '#jcmundo' , '#betaajudabeta' , '#edicao10' , '#panoramatvcultura' , '#sampa' , '#fotografia' , '#primeirahora' , '#domingodetremurasdv' , '#blogmundoafora' , '#vagadeemprego' , '#congonhas' , '#english' , '#feiras' , '#sharktankbr' , '#unicamp' , '#minhaamadinhanamega' , '#harvey' , '#órfãosremember' , '#m' , '#youtube' , '#museum' , '#níger' , '#neblina' , '#marketing' , '#ig' , '#euro2016' , '#arquitetura' , '#757live' , '#timbetaajudatimbeta' , '#ripamerica' , '#aloysiomigracaoagoranao' , '#pistadescendente' , '#lineup' , '#np' , '#p74' , '#adus' , '#sao_bento_do_sul' , '#livros' , '#sc' , '#videos' , '#gastronomia' , '#biq' , '#outono' , '#okok' , '#ahs7nofx' , '#liège' , '#gratuita' , '#p7' , '#diversos' , '#camara' , '#isis' , '#rj' , '#fotógrafo' , '#spn' , '#aquinta' , '#misterbrau' , '#ingles' , '#macron' , '#venidya' , '#abascal6mujeressinpiedad' , '#ecoturismo' , '#gleici' , '#copa2018' , '#getty' , '#aborto' , '#arqrio' , '#goldenglobes' , '#justpra' , '#domingo' , '#esl' , '#g1sp' , '#câmerarecord' , '#grevegeral' , '#vergonha' , '#sou' , '#partiu' , '#joamarda' , '#samba' , '#uoltab' , '#nãocontaláemcasa' , '#elloboinvademdq' , '#pense' , '#eurovision' , '#quintaclubesdv' , '#pioneiro' , '#johnbeta2' , '#jogosparalímpicos' , '#thevoicebrasil' , '#aljaniah' , '#aprizionnews' , '#elenunca' , '#diadasmulheres' , '#tererenewsjornal' , '#011' , '#13' , '#flamengo' , '#dica' , '#serra' , '#un' , '#dadaab' , '#jg' , '#16days' , '#vidanouk' , '#moria' , '#stop' , '#idiomas' , '#jaremaxmatosinhos' , '#compartilheaviagem' , '#rios' , '#pescaria' , '#timedo' , '#teamsol' , '#minuto' , '#tech' , '#foto' , '#askbelieber' , '#humor' , '#jesus' , '#vooz' , '#ac' , '#tuaradio' , '#noalaborto' , '#mg' , '#segundadetremurasdv' , '#sonharomundo' , '#sotu' , '#orangeisthenewblack' , '#tochaolímpica' , '#johnbeta' , '#quartadetremurasdv' , '#fulltime' , '#juizdefora' , '#idiotasúteis' , '#diálogosdafé' , '#capitãmarvel' , '#ndmais' , '#reciclagem' , '#cuecasmash' , '#evento' , '#architecturemw' , '#eventos' , '#amber' , '#grátis' , '#operamundi' , '#domingoespetacular' , '#fimdesemana' , '#pacaembu' , '#flynomixtudo' , '#renatogottschald' , '#gopdebate' , '#nexo' , '#altashoras' , '#jogosolimpicos' , '#edicao18' , '#mulherespodcasters' , '#kaysarcampeao' , '#ms' , '#focoemvocê' , '#élite' , '#integração' , '#operaçãobetalab' , '#ny' , '#a' , '#andremartinellinamash' , '#013' , '#genealogia' , '#dicacultural' , '#poa' , '#25a74' , '#musica' , '#geral' , '#t' , '#festa' , '#i' , '#opera' , '#msm' , '#vendanovadoimigrante' , '#prêmionansen' , '#music' , '#promoção' , '#vocabulario' , '#cifuentesdiceno' , '#13m' , '#forakaysar' , '#conversação' , '#portalamazônia' , '#carnaval' , '#j10' , '#nepal' , '#o' , '#edseis' , '#spfw' , '#ishelter' , '#leianosanta' , '#provincial' , '#outros' , '#costaeimigracao' , '#saopaulosao' , '#carabinieri' , '#devunit' , '#folhabv' , '#facebookpodeacabar' , '#jr24h' , '#vida' , '#frio' , '#ferias' , '#c' , '#salasocial' , '#zaatari' , '#ff' , '#por' , '#ibirapuera' , '#trabalhar' , '#gauchareporter' , '#legenda' , '#passeio' , '#festivaldojapao' , '#banksy' , '#esporteespetacular' , '#moda' , '#caxiasdosul' , '#rpsp' , '#n' , '#pnr' , '#heritagemw' , '#ouvindopodcast' , '#8' , '#ocupatudocontraogolpe' , '#jogosolímpicos' , '#nisilencioniolvido' , '#mi' , '#mosul' , '#joaquimdealmeida' , '#remaxmatosinhos' , '#justificando' , '#an' , '#ahs7' , '#ayotzinapa3años' , '#papáatm' , '#kaysarcampeão' , '#superarquivo' , '#ó' , '#elpaso' , '#nemapps' , '#cafecomjornal' , '#corinthians' , '#ccxp' , '#ourense' , '#oaxaca' , '#tanoar' , '#pp' , '#tvi24' , '#forzajuve' , '#giannitsa' , '#panamapapers' , '#filmes' , '#legacyofwar' , '#quintacomoclubesdv' , '#tercadetremurasdv' , '#estudarnocanada' , '#início' , '#diadascrianças' , '#bruna' , '#nãoa' , '#bestfanarmy' , '#camilaonlatina' , '#jovens' , '#copa' , '#hfrresort' , '#elemidia' , '#yahoo' , '#jovempan' , '#inovação' , '#guzerá' , '#ajuda' , '#café' , '#dutra' , '#peplenária' , '#carreira' , '#felizlunes' , '#01' , '#emn' , '#ti' , '#seguirconvida' , '#jcdebate' , '#nominuto' , '#cptm' , '#sabadodetremurasdv' , '#rotadooesteinforma' , '#intercambionocanada' , '#chomskyenuy' , '#lazer' , '#seuscu' , '#vene' , '#14j' , '#gusttavolima' , '#embaixadorchegou' , '#wdmr2019' , '#maislias' , '#relembremjsp' , '#guterres' , '#mpf' , '#cronaca' , '#vaicorinthians' , '#rádiocaxias' , '#vlog' , '#job' , '#natureza' , '#dn' , '#riopreto' , '#hojeemzh' , '#amazonas' , '#hypenews' , '#34' , '#cir' , '#tntweeters' , '#shalom' , '#monerosfinancieros' , '#withsyria' , '#startups' , '#sigodevo' , '#advogado' , '#lh4u' , '#umre' , '#jabaquara' , '#berrini' , '#salvador' , '#nice' , '#brunamarquezine' , '#bgs' , '#co' , '#iheartawards' , '#chiapas' , '#iwd2017' , '#deunatelha' , '#sp2' , '#colanadani' , '#fontanari' , '#assistência' , '#spnoar' , '#causaoperaria' , '#spiessantana' , '#ven' , '#teclasap' , '#lancenet' , '#mudanças' , '#miami' , '#nofilter' , '#destaque' , '#hora1' , '#omundocabeaqui' , '#ccxp2015' , '#rodoviadosimigrantes' , '#un70' , '#batalladelosgallos' , '#no' , '#follow' , '#eidomeni' , '#chamaolimpica' , '#segurança' , '#hbo' , '#gigantesdobrasil' , '#vozeshuffpost' , '#fra' , '#agoraébra' , '#boato' , '#ficaravena' , '#lovatics' , '#acab' , '#enfiemaspanelasnocu' , '#gameofthronesfinale']

# Create a boolean mask for rows containing unwanted hashtags in the 'text' column
unwanted_mask = df['text'].str.contains('|'.join(unwanted_hashtags), case=False)

# Apply the mask to filter out rows with unwanted hashtags
df_filtered = df[~unwanted_mask]

# Calculate the number of remaining rows in the filtered DataFrame
num_remaining_rows = len(df_filtered)

# Count the number of rows removed due to unwanted hashtags
num_removed_rows = unwanted_mask.sum()

# Calculate the number of remaining rows in the filtered DataFrame
num_remaining_rows = len(df_filtered)

print("Number of rows removed due to unwanted hashtags:", num_removed_rows)
print("Number of remaining rows:", num_remaining_rows)
# Out:
# Number of rows removed due to unwanted hashtags: 108293
# Number of remaining rows: 750539
